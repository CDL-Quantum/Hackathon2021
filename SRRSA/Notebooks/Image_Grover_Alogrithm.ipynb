# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import sys

sys.path.append('../Pyfiles')
# Pull in the helper files.
from ImageRead import *
from grover import *

# %% [markdown]
# # Image Grover Algorithm
# Saesun Kim
#
# This is the grover Algorithm using image data

# %%
path=r'..\\dataset\\Others\\'
name='P-'
imgdata=imageResize(callImage(2,path,name),16)
#Satellite images show Fort McMurray wildfire from space

# %%
plot_histogram(grover(5,imgdata), color='midnightblue', title="New Histogram",bar_labels =False,sort = 'desc')

# %%
#We need iteration at least

print(np.pi*np.sqrt(16*16)/4)

# maybe less ~
print(np.pi*np.sqrt(16*16/10)/4)
# Out:
# 12.566370614359172
# 3.9738353063184406

# %%
n_samples_show = 5
fig, axes = plt.subplots(nrows=2, ncols=n_samples_show, figsize=(20, 6))

for i in range(5):

    axes[0,i].imshow(imgdata, cmap='gray')
    axes[0,i].set_xticks([])
    axes[0,i].set_yticks([])

    axes[1,i].imshow(imigize1(grover(i,imgdata)), cmap='gray')
    axes[1,i].set_xticks([])
    axes[1,i].set_yticks([])
