# %% [markdown]
# # Test Binder environment setup with refresh

# %% [markdown]
# This notebook uses `seaborn`, which we have because we included it in our `requirements.txt` file

# %% [markdown]
# ## Setup our plotting

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Setup our imports

# %%
from numpy import random
from scipy.ndimage.filters import gaussian_filter

# %% [markdown]
# ## Make some plots!

# %%
x = random.randn(10,500)
x = gaussian_filter(x, [0, 10])
sns.lineplot(data=x.T,dashes=False,legend=None);

# %%
mat = random.randn(10,20)
sns.heatmap(mat);

# %% [markdown]
# Works!

# %% [markdown]
# now update and refresh

# %%
mat = random.randn(10,30)
sns.heatmap(mat);
