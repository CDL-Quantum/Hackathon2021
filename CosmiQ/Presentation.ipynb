# %%
import numpy as np
import matplotlib.pyplot as plt
import qiskit.pulse.library as pulse_lib

from scipy.optimize import curve_fit
from scipy.signal import find_peaks
from qiskit import IBMQ
from qiskit import pulse
from qiskit.compiler import assemble
from qiskit.tools.monitor import job_monitor

from gate_constructor import Calibration
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd

# %%
cal = Calibration()

# %% [markdown]
# # frequency 01

# %%
frequencies,schedules = cal.frequency01_schedules()
result_data = cal.run_schedule(schedules)
# Out:
# Job Status: job has successfully run

# %%
plt.scatter(np.real(result_data), np.imag(result_data))

# %%
cal.fit_results_f01(result_data,frequencies)

# %%
cal.df01_calib/cal.f01_default
# Out:
# -1.3514898986007677e-05

# %% [markdown]
# # amplitude 01

# %%
drive_powers,schedules = cal.amplitude01_schedules()
result_data = cal.run_schedule(schedules)
# Out:
# Job Status: job has successfully run

# %%
plt.scatter(np.real(result_data), np.imag(result_data))

# %%
cal.fit_results_a01(result_data,drive_powers)

# %%
cal.a01_calib
# Out:
# 0.14874896535391377

# %% [markdown]
# # frequency 12

# %%
frequencies,schedules = cal.frequency12_schedules()
result_data = cal.run_schedule(schedules)
# Out:
# Job Status: job has successfully run

# %%
plt.scatter(np.real(result_data), np.imag(result_data))

# %%
cal.fit_results_f12(result_data,frequencies)

# %%
cal.df12_calib
# Out:
# -347848394.2795225

# %% [markdown]
# # amplitude 12

# %%
drive_powers,schedules = cal.amplitude12_schedules()
result_data = cal.run_schedule(schedules)
# Out:
# Job Status: job has successfully run

# %%
plt.scatter(np.real(result_data), np.imag(result_data))

# %%
cal.fit_results_a12(result_data,drive_powers)

# %%
cal.a12_calib
# Out:
# 0.14836520637038897

# %% [markdown]
# # y 01

# %%
drive_powers,schedules = cal.amplitude_y01_schedules()
result_data = cal.run_schedule(schedules)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a91eabd96f63> in <module>
# ----> 1 drive_powers,schedules = cal.amplitude_y01_schedules()
#       2 result_data = cal.run_schedule(schedules)
#
# ~/Documents/GitHub/Hackathon2021/CosmiQ/gate_constructor.py in amplitude_y01_schedules(self, max_amp, qbit)
#     135                     pulse.shift_frequency(self.df01_calib, pulse.DriveChannel(qbit))
#     136                     pulse.play(yrot_pulse, pulse.DriveChannel(qbit)) #sqrt(y)
# --> 137                     pulse.play(self.pulse_rx01(), pulse.DriveChannel(qbit)) #x
#     138                     pulse.play(yrot_pulse, pulse.DriveChannel(qbit)) #sqrt(y)
#     139                     pulse.measure(qbit)
#
# NameError: name 'yrot_pulse' is not defined

# %%
plt.scatter(np.real(result_data), np.imag(result_data))

# %%
cal.fit_results_a_y01(result_data,drive_powers)

# %%
cal.y01_calib

# %% [markdown]
# # hadamard 12

# %%
drive_powers,schedules = cal.amplitude_h12_schedules()
result_data = cal.run_schedule(schedules)
#result_state = cal.classify_results(result_data)
# Out:
# Job Status: job has successfully run

# %%
plt.scatter(np.real(result_data), np.imag(result_data))
#plt.scatter(np.real(result_data[0,:]),np.imag(result_data[0,:]),s=1,c=result_state[0,:])
plt.axis('equal')
#print(np.unique(result_state,return_counts=True))
# Out:
# (-13.816549483741184,
#  -13.542219050909695,
#  -16.555329802207233,
#  -15.986566342115328)

# %%
cal.fit_results_a_h12(result_data,drive_powers)

# %%
cal.h12_calib
# Out:
# 0.01683629386842561

# %% [markdown]
# # hadamard 02

# %%
drive_powers,schedules = cal.amplitude_h02_schedules()
result_data = cal.run_schedule(schedules)
# Out:
# Job Status: job has successfully run

# %%
plt.scatter(np.real(result_data), np.imag(result_data))
#plt.scatter(np.real(result_data[0,:]),np.imag(result_data[0,:]),s=1,c=result_state[0,:])
plt.axis('equal')
#print(np.unique(result_state,return_counts=True))
# Out:
# (-14.87897265963008,
#  -14.455793558487041,
#  -14.280259587276799,
#  -13.50135787290624)

# %%
cal.fit_results_a_h02(result_data,drive_powers)

# %%
cal.h02_calib
# Out:
# 0.01923321081490083

# %% [markdown]
# # equal superposition

# %%
drive_powers,schedules = cal.amplitude_equal_superposition_schedules()
result_data = cal.run_schedule(schedules)
# Out:
# Job Status: job is actively running

# %%
plt.scatter(np.real(result_data), np.imag(result_data))

# %%
cal.fit_results_a_eq_sup(result_data,drive_powers)
