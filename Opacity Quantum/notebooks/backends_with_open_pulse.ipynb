# %%
import qiskit as qk

# %%
qk.IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
provider = qk.IBMQ.get_provider(
    hub="ibm-q-startup", group="opacity-quantum", project="testing"
)

# %%
provider.backends()
# Out:
# [<IBMQSimulator('ibmq_qasm_simulator') from IBMQ(hub='ibm-q-startup', group='opacity-quantum', project='testing')>,
#  <IBMQBackend('ibmqx2') from IBMQ(hub='ibm-q-startup', group='opacity-quantum', project='testing')>,
#  <IBMQBackend('ibmq_armonk') from IBMQ(hub='ibm-q-startup', group='opacity-quantum', project='testing')>,
#  <IBMQBackend('ibmq_santiago') from IBMQ(hub='ibm-q-startup', group='opacity-quantum', project='testing')>,
#  <IBMQBackend('ibmq_bogota') from IBMQ(hub='ibm-q-startup', group='opacity-quantum', project='testing')>,
#  <IBMQBackend('ibmq_casablanca') from IBMQ(hub='ibm-q-startup', group='opacity-quantum', project='testing')>]

# %%
for backend in provider.backends(open_pulse=True):
    print(backend)
    qk.visualization.plot_gate_map(backend)
# Out:
# ibmq_armonk
# ibmq_bogota
# ibmq_casablanca
